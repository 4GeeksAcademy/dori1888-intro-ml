# %% [markdown]
# # Proyecto: Decision Tree (Preprocesado + Selección de características + CV + Modelo final)
#
# Objetivo: construir un modelo de Árbol de Decisión para predecir la variable objetivo, realizando:
# - revisión de duplicados
# - tratamiento de ceros clínicamente imposibles como NaN
# - análisis de % de faltantes
# - eliminación de variables con demasiados faltantes (Insulin)
# - imputación avanzada (KNN)
# - estudio de outliers
# - cross validation
# - selección de características (RFECV)
# - optimización (GridSearchCV)
# - visualización del árbol
# - guardado del modelo

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, cross_val_score
from sklearn.impute import KNNImputer
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score
from sklearn.feature_selection import RFECV

import joblib

# %%
# CARGA DE DATOS
df = pd.read_csv("../data/raw/internal-link(6).csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
print("Shape:", df.shape)
df.info()
df.describe()
# Out:
# Shape: (768, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# ...

# %%
# REVISIÓN DE DUPLICADOS

dup = df.duplicated().sum()
print("Duplicados:", dup)

if dup > 0:
    df = df.drop_duplicates().reset_index(drop=True)
    print("Duplicados eliminados. Nuevo shape:", df.shape)
# Out:
# Duplicados: 0

# %% [markdown]
# ## Tratamiento de ceros clínicamente imposibles
#
# En variables clínicas como Glucose, BloodPressure, SkinThickness, Insulin y BMI, el valor 0 no es fisiológicamente válido, por lo que se tratará como dato faltante (NaN).

# %%
# CEROS CLÍNICAMENTE IMPOSIBLES (0 = missing encubierto)

cols_zero_as_nan = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]
df[cols_zero_as_nan] = df[cols_zero_as_nan].replace(0, np.nan)

df[cols_zero_as_nan].isna().sum()
# Out:
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# Insulin          374
# BMI               11
# dtype: int64

# %%
# % DE FALTANTES
missing_pct = (df.isna().mean()*100).round(2).sort_values(ascending=False)
missing_pct[missing_pct > 0]
# Out:
# Insulin          48.70
# SkinThickness    29.56
# BloodPressure     4.56
# BMI               1.43
# Glucose           0.65
# dtype: float64

# %%
# ELIMINAR 'Insulin' POR ALTO % DE FALTANTES (no imputable de forma fiable)
if "Insulin" in df.columns:
    insulin_missing_pct = df["Insulin"].isna().mean() * 100
    print(f"% faltantes en Insulin: {insulin_missing_pct:.2f}%")
    
    if insulin_missing_pct >= 40:
        df = df.drop(columns=["Insulin"])
        print("Columna 'Insulin' eliminada. Nuevo shape:", df.shape)
else:
    print("La columna 'Insulin' ya no está en el dataset.")
# Out:
# % faltantes en Insulin: 48.70%
# Columna 'Insulin' eliminada. Nuevo shape: (768, 8)

# %%
# ELIMINAR 'Insulin' POR ALTO % DE FALTANTES (no imputable de forma fiable)
if "Insulin" in df.columns:
    insulin_missing_pct = df["Insulin"].isna().mean() * 100
    print(f"% faltantes en Insulin: {insulin_missing_pct:.2f}%")
    
    # Umbral recomendado: >= 40% faltantes -> eliminar
    if insulin_missing_pct >= 40:
        df = df.drop(columns=["Insulin"])
        print("Columna 'Insulin' eliminada. Nuevo shape:", df.shape)
else:
    print("La columna 'Insulin' ya no está en el dataset.")
# Out:
# La columna 'Insulin' ya no está en el dataset.

# %% [markdown]
# Insulin tiene ceros no fisiológicos, por lo que se tratan como missing (NaN) y se imputan.

# %% [markdown]
# ## Imputación con KNNImputer
#
# Se utiliza **KNNImputer** por ser un método multivariante que aprovecha la relación entre variables, mejorando la imputación frente a la mediana.

# %%
# IMPUTACIÓN MEJOR (KNN, NO MEDIANA
num_cols = df.select_dtypes(include="number").columns
imputer = KNNImputer(n_neighbors=5)

df[num_cols] = imputer.fit_transform(df[num_cols])

print("NaN totales tras imputación:", df.isna().sum().sum())
# Out:
# NaN totales tras imputación: 0

# %% [markdown]
# ## Estudio de outliers (IQR)
#
# Se analizan valores atípicos mediante el criterio IQR.
# No necesariamente se eliminan (pueden ser valores clínicos reales), pero se reportan para documentar su presencia.

# %%
# OUTLIERS

def outlier_summary_iqr(data, cols):
    summary = []
    for c in cols:
        q1, q3 = data[c].quantile([0.25, 0.75])
        iqr = q3 - q1
        low, high = q1 - 1.5*iqr, q3 + 1.5*iqr
        n_out = ((data[c] < low) | (data[c] > high)).sum()
        summary.append((c, n_out, round(n_out/len(data)*100, 2)))
    return pd.DataFrame(summary, columns=["col", "n_outliers", "%_outliers"]).sort_values("%_outliers", ascending=False)

target = "Outcome"  # si tu target se llama distinto, cámbialo aquí
feature_cols = [c for c in df.columns if c != target]

outlier_report = outlier_summary_iqr(df, feature_cols)
outlier_report
# Out:
#                         col  n_outliers  %_outliers
# 5  DiabetesPedigreeFunction          29        3.78
# 2             BloodPressure          14        1.82
# 6                       Age           9        1.17
# 4                       BMI           8        1.04
# 3             SkinThickness           6        0.78
# 0               Pregnancies           4        0.52
# 1                   Glucose           0        0.00

# %%
top_out = outlier_report["col"].head(4).tolist()
df[top_out].plot(kind="box", figsize=(10,5))
plt.tight_layout()
plt.show()

# %%
# X / y
X = df.drop(columns=[target])
y = df[target]

X.shape, y.shape
# Out:
# ((768, 7), (768,))

# %% [markdown]
# ## Cross Validation (F1)
#
# Se evalúa el rendimiento del Árbol de Decisión mediante validación cruzada estratificada usando F1.

# %%
# CROSS VALIDATION

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

base_tree = DecisionTreeClassifier(random_state=42)
cv_f1 = cross_val_score(base_tree, X, y, cv=cv, scoring="f1")

print("F1 CV mean:", round(cv_f1.mean(), 3), "| std:", round(cv_f1.std(), 3))
# Out:
# F1 CV mean: 0.528 | std: 0.028

# %% [markdown]
# ## Selección de características (RFECV)
#
# Se usa **RFECV** para seleccionar variables sin elegir un número arbitrario, apoyándose en validación cruzada.

# %% [markdown]
# ## Selección de características y análisis de multicolinealidad

# %%
# SELECCIÓN DE CARACTERÍSTICAS (RFECV)

selector = RFECV(
    estimator=DecisionTreeClassifier(random_state=42),
    step=1,
    cv=cv,
    scoring="f1",
    n_jobs=-1
)

selector.fit(X, y)

selected_rfecv = X.columns[selector.support_].tolist()
print("Features seleccionadas por RFECV:", selected_rfecv)
print("N features (RFECV):", len(selected_rfecv))
# Out:
# Features seleccionadas por RFECV: ['Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age']
# N features (RFECV): 6

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
sns.heatmap(df.drop(columns=[target]).corr(), annot=True, cmap="coolwarm")
plt.title("Matriz de correlación de variables")
plt.show()

# %%
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import MinMaxScaler

X_full = df.drop(columns=[target])
y_full = df[target]

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X_full)

chi2_selector = SelectKBest(score_func=chi2, k="all")
chi2_selector.fit(X_scaled, y_full)

chi2_scores = pd.DataFrame({
    "Feature": X_full.columns,
    "Chi2_Score": chi2_selector.scores_
}).sort_values("Chi2_Score", ascending=False)

chi2_scores
# Out:
#                     Feature  Chi2_Score
# 1                   Glucose   14.569596
# 6                       Age    8.205691
# 0               Pregnancies    6.559982
# 4                       BMI    5.151150
# 5  DiabetesPedigreeFunction    2.758584
# 3             SkinThickness    2.616170
# 2             BloodPressure    0.752421

# %%
from sklearn.feature_selection import mutual_info_classif

mi_scores = mutual_info_classif(X_full, y_full, random_state=42)

mi_df = pd.DataFrame({
    "Feature": X_full.columns,
    "MI_Score": mi_scores
}).sort_values("MI_Score", ascending=False)

mi_df
# Out:
#                     Feature  MI_Score
# 1                   Glucose  0.114351
# 4                       BMI  0.082337
# 6                       Age  0.074807
# 0               Pregnancies  0.042371
# 3             SkinThickness  0.033393
# 5  DiabetesPedigreeFunction  0.014785
# 2             BloodPressure  0.004044

# %%
# CONSENSO DE SELECCIÓN (RFECV + Chi2 + Mutual Information)
# Objetivo: no eliminar variables que otros métodos indican como más influyentes.

top_k = 5  # ajusta si quieres más/menos variables de cada ranking
top_chi2 = chi2_scores["Feature"].head(top_k).tolist()
top_mi = mi_df["Feature"].head(top_k).tolist()

selected_features = sorted(set(selected_rfecv) | set(top_chi2) | set(top_mi))

print("Top Chi2:", top_chi2)
print("Top MI:", top_mi)
print("RFECV:", selected_rfecv)
print("\nFeatures finales (consenso):", selected_features)
print("N features (final):", len(selected_features))
# Out:
# Top Chi2: ['Glucose', 'Age', 'Pregnancies', 'BMI', 'DiabetesPedigreeFunction']
# Top MI: ['Glucose', 'BMI', 'Age', 'Pregnancies', 'SkinThickness']
# RFECV: ['Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age']
#
# Features finales (consenso): ['Age', 'BMI', 'BloodPressure', 'DiabetesPedigreeFunction', 'Glucose', 'Pregnancies', 'SkinThickness']
# N features (final): 7

# %%
# CONSENSO DE SELECCIÓN (RFECV + Chi2 + Mutual Information)
top_k = 5
top_chi2 = chi2_scores["Feature"].head(top_k).tolist()
top_mi = mi_df["Feature"].head(top_k).tolist()

selected_features = sorted(set(selected_rfecv) | set(top_chi2) | set(top_mi))

print("Top Chi2:", top_chi2)
print("Top MI:", top_mi)
print("RFECV:", selected_rfecv)
print("\nFeatures finales (consenso):", selected_features)
print("N features (final):", len(selected_features))
# Out:
# Top Chi2: ['Glucose', 'Age', 'Pregnancies', 'BMI', 'DiabetesPedigreeFunction']
# Top MI: ['Glucose', 'BMI', 'Age', 'Pregnancies', 'SkinThickness']
# RFECV: ['Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age']
#
# Features finales (consenso): ['Age', 'BMI', 'BloodPressure', 'DiabetesPedigreeFunction', 'Glucose', 'Pregnancies', 'SkinThickness']
# N features (final): 7

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_df = pd.DataFrame()
vif_df["Feature"] = X_full.columns
vif_df["VIF"] = [
    variance_inflation_factor(X_full.values, i)
    for i in range(X_full.shape[1])
]

vif_df.sort_values("VIF", ascending=False)
# Out:
#                     Feature        VIF
# 4                       BMI  38.222251
# 2             BloodPressure  32.039169
# 1                   Glucose  18.549377
# 3             SkinThickness  18.444181
# 6                       Age  14.432318
# 0               Pregnancies   3.274915
# 5  DiabetesPedigreeFunction   3.143356

# %% [markdown]
# Si VIF > 5 hay multicolinealidad moderada; si VIF > 10 es alta. En caso necesario se eliminarían/combinarían variables con VIF alto.

# %% [markdown]
# **Conclusión:**
# Las variables seleccionadas para el modelo se justifican mediante:
# - análisis de correlación,
# - métricas estadísticas (Chi² y Mutual Information),
# - y análisis de multicolinealidad mediante VIF.
#
# Este proceso garantiza una selección de características informada antes del entrenamiento.

# %%
# TRAIN / TEST CON FEATURES SELECCIONADAS

X_sel = X[selected_features]

X_train, X_test, y_train, y_test = train_test_split(
    X_sel, y, test_size=0.2, random_state=42, stratify=y
)

X_train.shape, X_test.shape
# Out:
# ((614, 7), (154, 7))

# %% [markdown]
# ## Optimización del Árbol (GridSearchCV)
#
# Se optimiza el Árbol de Decisión usando GridSearchCV con validación cruzada estratificada y F1 como métrica.

# %%
# GRIDSEARCHCV FINAL

param_grid = {
    "max_depth": [2, 3, 4, 5, 6, None],
    "min_samples_split": [2, 5, 10, 20],
    "min_samples_leaf": [1, 2, 4, 8],
    "criterion": ["gini", "entropy"]
}

grid = GridSearchCV(
    DecisionTreeClassifier(random_state=42),
    param_grid=param_grid,
    scoring="f1",
    cv=cv,
    n_jobs=-1
)

grid.fit(X_train, y_train)
best_model = grid.best_estimator_

print("Best params:", grid.best_params_)
# Out:
# Best params: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 2, 'min_samples_split': 2}

# %%
# EVALUACION FINAL

y_pred = best_model.predict(X_test)

print("Accuracy:", round(accuracy_score(y_test, y_pred), 3))
print("F1:", round(f1_score(y_test, y_pred), 3))
print("\nMatriz de confusión:\n", confusion_matrix(y_test, y_pred))
print("\nReporte:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.721
# F1: 0.566
#
# Matriz de confusión:
#  [[83 17]
#  [26 28]]
#
# Reporte:
#                precision    recall  f1-score   support
#
#          0.0       0.76      0.83      0.79       100
#          1.0       0.62      0.52      0.57        54
#
#     accuracy                           0.72       154
#    macro avg       0.69      0.67      0.68       154
# weighted avg       0.71      0.72      0.71       154

# %% [markdown]
# ## Visualización del árbol
#
# Para que sea legible, se limita la profundidad **solo en el gráfico** (`max_depth=4`).

# %%
# PLOT DEL ÁRBOL

plt.figure(figsize=(24, 12))
plot_tree(
    best_model,
    feature_names=selected_features,
    class_names=["No", "Yes"],
    filled=True,
    rounded=True,
    fontsize=10,
    max_depth=4
)
plt.tight_layout()
plt.show()

# %%
# GUARDAR MODELO

joblib.dump(best_model, "best_decision_tree.pkl")
joblib.dump(selected_features, "selected_features.pkl")
print("Guardado: best_decision_tree.pkl y selected_features.pkl")
# Out:
# Guardado: best_decision_tree.pkl y selected_features.pkl

# %% [markdown]
# # Conclusión
#
# - Se revisaron y eliminaron duplicados para evitar sesgos.
# - Se trataron ceros clínicamente imposibles como valores faltantes (NaN).
# - Se analizó el porcentaje de faltantes por columna antes de imputar.
# - Se eliminó **Insulin** cuando superó el 40% de valores faltantes para mejorar robustez.
# - Se aplicó imputación con **KNNImputer** (multivariante) para una imputación más informativa.
# - Se reportaron outliers mediante IQR para documentar valores atípicos.
# - Se aplicó **Cross Validation** con F1 para evaluar estabilidad.
# - Se realizó selección de características con **RFECV** evitando una elección arbitraria.
# - Se optimizó el modelo final con GridSearchCV, se visualizó el árbol y se guardó el modelo entrenado.
# - La variable **Insulin** no está presente en este dataset, por lo que no aplica su análisis/eliminación por porcentaje de valores faltantes.
